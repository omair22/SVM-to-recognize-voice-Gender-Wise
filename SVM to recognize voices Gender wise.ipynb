# %% [markdown]
# #                       **METHODOLOGY**
#
# 1. Importing the dataset.
# 2. Data wrangling: Encoding categorical values
# 3. Feature selection based on correlation of variables.
# 2. Splitting the dataset into independent and dependent variables.
# 3. Model : Then we decide which model is more suitable for our dataset. Here we use **SVM**.
# 4. Determining Accuracy: Using different accuracy measures we predict the
# accuracy of model. Here we use confusion matrix

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **DATA EXTRACTION**
# Extracting the data and finding information about it

# %%
df = pd.read_excel("voice.xlsx")

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25  ...    maxdom   dfrange   modindx  label
# 0  0.059781  0.064241  0.032027  0.015071  ...  0.007812  0.000000  0.000000   male
# 1  0.066009  0.067310  0.040229  0.019414  ...  0.054688  0.046875  0.052632   male
# 2  0.077316  0.083829  0.036718  0.008701  ...  0.015625  0.007812  0.046512   male
# 3  0.151228  0.072111  0.158011  0.096582  ...  0.562500  0.554688  0.247119   male
# 4  0.135120  0.079146  0.124656  0.078720  ...  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (3168, 21)

# %%
df.describe()
# Out:
#           meanfreq           sd  ...      dfrange      modindx
# count  3168.000000  3168.000000  ...  3168.000000  3168.000000
# mean      0.180907     0.057126  ...     4.994630     0.173752
# std       0.029918     0.016652  ...     3.520039     0.119454
# min       0.039363     0.018363  ...     0.000000     0.000000
# 25%       0.163662     0.041954  ...     2.044922     0.099766
# 50%       0.184838     0.059155  ...     4.945312     0.139357
# 75%       0.199146     0.067020  ...     6.992188     0.209183
# max       0.251124     0.115273  ...    21.843750     0.932374
#
# [8 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %% [markdown]
# ## **DATA WRANGLING**

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

df['label']= le.fit_transform(df['label'])

# %% [markdown]
# ## **DATA VISUALIZATION**

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot = True)

# %% [markdown]
# ## **Checking Correlation**

# %%
abs(df.corr()['label']).sort_values(ascending=False)
# Out:
# label       1.000000
# meanfun     0.833921
# IQR         0.618916
# Q25         0.511455
# sp.ent      0.490552
# sd          0.479539
# sfm         0.357499
# centroid    0.337415
# meanfreq    0.337415
# median      0.283919
# maxdom      0.195657
# mindom      0.194974
# dfrange     0.192213
# meandom     0.191067
# mode        0.171775
# maxfun      0.166461
# minfun      0.136692
# kurt        0.087195
# Q75         0.066906
# skew        0.036627
# modindx     0.030801
# Name: label, dtype: float64

# %% [markdown]
# ### **Feature Selection**

# %%
df.drop(["kurt", "Q75","skew","modindx"], axis = 1, inplace = True)

# %% [markdown]
# **Dividing dataset into independent  and dependent variables.**

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ## **Generating Model**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
model=svclassifier.fit(x_train, y_train)

# %% [markdown]
# ## **Evaluation**

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[260  41]
#  [  3 330]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       301
#            1       0.89      0.99      0.94       333
#
#     accuracy                           0.93       634
#    macro avg       0.94      0.93      0.93       634
# weighted avg       0.94      0.93      0.93       634
